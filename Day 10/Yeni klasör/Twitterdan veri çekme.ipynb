# %%
pip install twython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: twython in c:\users\bayan feminist\appdata\roaming\python\python39\site-packages (3.9.1)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in c:\users\bayan feminist\appdata\roaming\python\python39\site-packages (from twython) (1.3.1)
# Requirement already satisfied: requests>=2.1.0 in c:\programdata\anaconda3\lib\site-packages (from twython) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bayan feminist\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.4.0->twython) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from twython import Twython

# %%
dir(Twython)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_error_message',
#  '_request',
#  'add_list_member',
#  'construct_api_url',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_list_members',
#  'create_metadata',
#  'create_mute',
#  'create_place',
#  'create_saved_search',
#  'cursor',
#  'delete',
#  'delete_list',
#  'delete_list_member',
#  'delete_list_members',
#  'destroy_block',
#  'destroy_direct_message',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
#  'encode',
#  'get',
#  'get_account_settings',
#  'get_application_rate_limit_status',
#  'get_authentication_tokens',
#  'get_authorized_tokens',
#  'get_available_trends',
#  'get_closest_trends',
#  'get_contributees',
#  'get_contributors',
#  'get_direct_message',
#  'get_direct_messages',
#  'get_favorites',
#  'get_followers_ids',
#  'get_followers_list',
#  'get_friends_ids',
#  'get_friends_list',
#  'get_geo_info',
#  'get_home_timeline',
#  'get_incoming_friendship_ids',
#  'get_lastfunction_header',
#  'get_list_members',
#  'get_list_memberships',
#  'get_list_statuses',
#  'get_list_subscribers',
#  'get_list_subscriptions',
#  'get_mentions_timeline',
#  'get_oembed_tweet',
#  'get_outgoing_friendship_ids',
#  'get_place_trends',
#  'get_privacy_policy',
#  'get_profile_banner_sizes',
#  'get_retweeters_ids',
#  'get_retweets',
#  'get_saved_searches',
#  'get_sent_messages',
#  'get_similar_places',
#  'get_specific_list',
#  'get_supported_languages',
#  'get_tos',
#  'get_twitter_configuration',
#  'get_user_ids_of_blocked_retweets',
#  'get_user_suggestions',
#  'get_user_suggestions_by_slug',
#  'get_user_suggestions_statuses_by_slug',
#  'get_user_timeline',
#  'html_for_tweet',
#  'invalidate_token',
#  'is_list_member',
#  'is_list_subscriber',
#  'list_block_ids',
#  'list_blocks',
#  'list_mute_ids',
#  'list_mutes',
#  'lookup_friendships',
#  'lookup_status',
#  'lookup_user',
#  'obtain_access_token',
#  'post',
#  'remove_profile_banner',
#  'report_spam',
#  'request',
#  'retweet',
#  'retweeted_of_me',
#  'reverse_geocode',
#  'search',
#  'search_gen',
#  'search_geo',
#  'search_users',
#  'send_direct_message',
#  'show_friendship',
#  'show_lists',
#  'show_owned_lists',
#  'show_saved_search',
#  'show_status',
#  'show_user',
#  'subscribe_to_list',
#  'unicode2utf8',
#  'unsubscribe_from_list',
#  'update_account_settings',
#  'update_delivery_service',
#  'update_friendship',
#  'update_list',
#  'update_profile',
#  'update_profile_background_image',
#  'update_profile_banner_image',
#  'update_profile_colors',
#  'update_profile_image',
#  'update_status',
#  'update_status_with_media',
#  'upload_media',
#  'upload_video',
#  'verify_credentials']

# %%
CONSUMER_KEY = '0pJRCT1emkOcrtxHl7lMN4N5A'
CONSUMER_SECRET = 'IS4Gxcx1aQ1c5Hyei5PSePLS37IcVmYBT8Qt1t4IOxmLIxJD42'

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET)

# %%
results=twitter.search(q="TRump",count=100)

# %%
results
# Out:
# {'statuses': [{'created_at': 'Sun Oct 30 07:12:33 +0000 2022',
#    'id': 1586617033109786624,
#    'id_str': '1586617033109786624',
#    'text': '@TheLeoTerrell But this guy, who history shows he never pays contractors… total trust. https://t.co/CzG56xA5TF',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TheLeoTerrell',
#       'name': 'TheLeoTerrell',
#       'id': 1212806053907185664,
#       'id_str': '1212806053907185664',
#       'indices': [0, 14]}],
#     'urls': [{'url': 'https://t.co/CzG56xA5TF',
#       'expanded_url': 'https://www.northjersey.com/story/news/columnists/mike-kelly/2020/01/24/donald-trump-still-owes-money-to-contractors-who-built-taj-mahal-atlantic-city/4547037002/',
#       'display_url': 'northjersey.com/story/news/col…',
#       'indices': [87, 110]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1586577370810458113,
#    'in_reply_to_status_id_str': '1586577370810458113',
#    'in_reply_to_user_id': 1212806053907185664,
#    'in_reply_to_user_id_str': '1212806053907185664',
#    'in_reply_to_screen_name': 'TheLeoTerrell',
#    'user': {'id': 2619172510,
#     'id_str': '2619172510',
#     'name': 'He looks like a Tyrant. 🤬🤡💩',
#     'screen_name': 'LynneJordanActs',
#     'location': '',
#     'description': 'He armed us. Divided us. Stole the money. Sent in the Goons. During a plague. Looks like a Tyrant to me! Punch Up. Never Across. Never, Down. I have a list.🤗',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 184,
#     'friends_count': 1285,
#     'listed_count': 5,
#     'created_at': 'Wed Jun 18 05:04:30 +0000 2014',
#     'favourites_count': 12297,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6205,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '8B542B',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/951988530535915520/i6_KU6Sb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/951988530535915520/i6_KU6Sb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2619172510/1596075727',
#     'profile_link_color': '9D582E',
#     'profile_sidebar_border_color': 'D9B17E',
#     'profile_sidebar_fill_color': 'EADEAA',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:12:32 +0000 2022',
#    'id': 1586617029548810244,
#    'id_str': '1586617029548810244',
#    'text': '@blueheartedly He should reinstate it but I hope Trump does not return.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'blueheartedly',
#       'name': '🗳4fuxake!🗳',
#       'id': 702577251020382209,
#       'id_str': '702577251020382209',
#       'indices': [0, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1586339257928470537,
#    'in_reply_to_status_id_str': '1586339257928470537',
#    'in_reply_to_user_id': 702577251020382209,
#    'in_reply_to_user_id_str': '702577251020382209',
#    'in_reply_to_screen_name': 'blueheartedly',
#    'user': {'id': 47800374,
#     'id_str': '47800374',
#     'name': 'Bartleby the Scrivener',
#     'screen_name': 'BartlebyX',
#     'location': 'Taylor, MI',
#     'description': 'John 3:16, Christian, dad, pro adoption, INTJ, nerd, libertarian, gamer, Miwok/Irish ancestry.  Human passing Nexus 6, and autistic (so please be patient)',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 491,
#     'friends_count': 1028,
#     'listed_count': 3,
#     'created_at': 'Wed Jun 17 01:07:40 +0000 2009',
#     'favourites_count': 68060,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 20491,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1478884039704592388/ps4_hqz8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1478884039704592388/ps4_hqz8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/47800374/1623695354',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:12:31 +0000 2022',
#    'id': 1586617026306457600,
#    'id_str': '1586617026306457600',
#    'text': 'RT @chitaglorya3rd: Oh my god! LOOK AT THIS!\n\nYou cant miss it!\n\nSales of the revolutionary new #memetoken start in a few days \n\nA huge tea…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'memetoken', 'indices': [96, 106]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'chitaglorya3rd',
#       'name': 'chita glorya🍒',
#       'id': 1534383410151829508,
#       'id_str': '1534383410151829508',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1395520387841019904,
#     'id_str': '1395520387841019904',
#     'name': 'Tommy Slebew',
#     'screen_name': '0xShelbyWin',
#     'location': 'Shelby Company Limited',
#     'description': "by oouwdaaa of da peaky fooooocking bloinde'sssz!",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 138,
#     'friends_count': 2783,
#     'listed_count': 5,
#     'created_at': 'Thu May 20 23:23:04 +0000 2021',
#     'favourites_count': 1022,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 19104,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1519484200679661568/NW_TWph5_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1519484200679661568/NW_TWph5_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1395520387841019904/1623783849',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 03:13:44 +0000 2022',
#     'id': 1586556931891920899,
#     'id_str': '1586556931891920899',
#     'text': 'Oh my god! LOOK AT THIS!\n\nYou cant miss it!\n\nSales of the revolutionary new #memetoken start in a few days \n\nA huge… https://t.co/T5nEVZB5CP',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'memetoken', 'indices': [76, 86]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/T5nEVZB5CP',
#        'expanded_url': 'https://twitter.com/i/web/status/1586556931891920899',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1534383410151829508,
#      'id_str': '1534383410151829508',
#      'name': 'chita glorya🍒',
#      'screen_name': 'chitaglorya3rd',
#      'location': 'twitter ',
#      'description': 'Social media & crypto project promoter 📈 ||#cutetesty vouch @winnerchita || 3rd reborn || worldwide 🌍 pickaw apps ♻️',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 116744,
#      'friends_count': 385,
#      'listed_count': 1427,
#      'created_at': 'Wed Jun 08 03:55:10 +0000 2022',
#      'favourites_count': 44,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1497,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1534385923290714112/QXiTKjzx_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1534385923290714112/QXiTKjzx_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1534383410151829508/1655519970',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5834,
#     'favorite_count': 5649,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5834,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:12:31 +0000 2022',
#    'id': 1586617025757151235,
#    'id_str': '1586617025757151235',
#    'text': '@ProtocolUpdate @SpeakerPelosi Do show evidence of your allegations or shut up about them. Trump made a quarter of… https://t.co/TvG8HxOhF5',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProtocolUpdate',
#       'name': '฿lockchain ฿oy (💙,🧡)',
#       'id': 1404866110059548672,
#       'id_str': '1404866110059548672',
#       'indices': [0, 15]},
#      {'screen_name': 'SpeakerPelosi',
#       'name': 'Nancy Pelosi',
#       'id': 15764644,
#       'id_str': '15764644',
#       'indices': [16, 30]}],
#     'urls': [{'url': 'https://t.co/TvG8HxOhF5',
#       'expanded_url': 'https://twitter.com/i/web/status/1586617025757151235',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1586586247287304193,
#    'in_reply_to_status_id_str': '1586586247287304193',
#    'in_reply_to_user_id': 1404866110059548672,
#    'in_reply_to_user_id_str': '1404866110059548672',
#    'in_reply_to_screen_name': 'ProtocolUpdate',
#    'user': {'id': 1541843374029918209,
#     'id_str': '1541843374029918209',
#     'name': 'Jason Carpenter',
#     'screen_name': 'Parzival418',
#     'location': 'Punjar, Aerth',
#     'description': 'Future dad. Goblin king. Pig faced orcs is best. #DCCrpg is the greatest fantasy rpg. #OtherworldMinis are the best minis. Fight me. Here for games and minis.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 108,
#     'friends_count': 335,
#     'listed_count': 1,
#     'created_at': 'Tue Jun 28 17:58:10 +0000 2022',
#     'favourites_count': 1945,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3859,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1541843704339742721/wey8Jqax_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1541843704339742721/wey8Jqax_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1541843374029918209/1656439289',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:12:31 +0000 2022',
#    'id': 1586617024775847936,
#    'id_str': '1586617024775847936',
#    'text': 'RT @taegiveaway: Oh my god! LOOK AT THIS! \n\nYou cant miss it! \n\nSales of the revolutionary new #memetoken start in a few days \n\nA huge team…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'memetoken', 'indices': [95, 105]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'taegiveaway',
#       'name': 'taeby',
#       'id': 1353847968919547904,
#       'id_str': '1353847968919547904',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1358592231964172290,
#     'id_str': '1358592231964172290',
#     'name': 'eskrim 🍨🍰',
#     'screen_name': 'selenaxlele',
#     'location': 'Indonesia',
#     'description': '𓆩⚜️𓆪 Akun Mobile Legend ku kalau gacha emang bau, asalkan jangan akun hunterku yang bau. 😎🤙 🍓tg: meylialia 🍎 discord: meylia#6653',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 81,
#     'friends_count': 4214,
#     'listed_count': 5,
#     'created_at': 'Mon Feb 08 01:43:44 +0000 2021',
#     'favourites_count': 4176,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 21323,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1526786524301635585/EuUhqTBB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1526786524301635585/EuUhqTBB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1358592231964172290/1664214622',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 14:01:25 +0000 2022',
#     'id': 1586357542531510272,
#     'id_str': '1586357542531510272',
#     'text': 'Oh my god! LOOK AT THIS! \n\nYou cant miss it! \n\nSales of the revolutionary new #memetoken start in a few days \n\nA hu… https://t.co/NnxKf6ySuI',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'memetoken', 'indices': [78, 88]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/NnxKf6ySuI',
#        'expanded_url': 'https://twitter.com/i/web/status/1586357542531510272',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1353847968919547904,
#      'id_str': '1353847968919547904',
#      'name': 'taeby',
#      'screen_name': 'taegiveaway',
#      'location': 'check list active giveaways ↓',
#      'description': "I'm here to help you promote your project. Posting giveaways daily 🧚\u200d♀️ proofs winner : #taefairy",
#      'url': 'https://t.co/vVo16AnwbU',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/vVo16AnwbU',
#          'expanded_url': 'https://twitter.com/i/events/1483286885791375365',
#          'display_url': 'twitter.com/i/events/14832…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 262094,
#      'friends_count': 887,
#      'listed_count': 2848,
#      'created_at': 'Mon Jan 25 23:31:33 +0000 2021',
#      'favourites_count': 3511,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 36228,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1433287575741943811/yGxUdigL_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1433287575741943811/yGxUdigL_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1353847968919547904/1635578382',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6889,
#     'favorite_count': 6714,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6889,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:12:31 +0000 2022',
#    'id': 1586617024339492864,
#    'id_str': '1586617024339492864',
#    'text': 'RT @jairbolsonaro: - Meu obrigado a Donald Trump pelo apoio! Sinto orgulho por ver que nosso trabalho por um Brasil mais seguro e mais livr…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jairbolsonaro',
#       'name': 'Jair M. Bolsonaro 2️⃣2️⃣',
#       'id': 128372940,
#       'id_str': '128372940',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 247141840,
#     'id_str': '247141840',
#     'name': 'Christian Lincoln',
#     'screen_name': 'ChristianLincol',
#     'location': 'Porto Ferreira-SP-Brasil',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 15,
#     'friends_count': 123,
#     'listed_count': 0,
#     'created_at': 'Fri Feb 04 05:01:18 +0000 2011',
#     'favourites_count': 2264,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 507,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000156679384/b3ba91de9366f8e201e078d7d06d1921_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000156679384/b3ba91de9366f8e201e078d7d06d1921_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 02:09:53 +0000 2022',
#     'id': 1586540865618591744,
#     'id_str': '1586540865618591744',
#     'text': '- Meu obrigado a Donald Trump pelo apoio! Sinto orgulho por ver que nosso trabalho por um Brasil mais seguro e mais… https://t.co/6JVsM2kMQY',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/6JVsM2kMQY',
#        'expanded_url': 'https://twitter.com/i/web/status/1586540865618591744',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 128372940,
#      'id_str': '128372940',
#      'name': 'Jair M. Bolsonaro 2️⃣2️⃣',
#      'screen_name': 'jairbolsonaro',
#      'location': 'Brasília, Brasil',
#      'description': 'Capitão Paraquedista do Exército Brasileiro. Presidente da República Federativa do Brasil. Candidato à reeleição com o número 2⃣2⃣.',
#      'url': 'https://t.co/DzletgH0tv',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/DzletgH0tv',
#          'expanded_url': 'https://t.me/jairbolsonarobrasil',
#          'display_url': 't.me/jairbolsonarob…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9626169,
#      'friends_count': 518,
#      'listed_count': 8606,
#      'created_at': 'Wed Mar 31 23:13:44 +0000 2010',
#      'favourites_count': 5979,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 15358,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '175C17',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1559734581942800385/qtN3jE9H_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1559734581942800385/qtN3jE9H_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/128372940/1663337696',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'A4E37F',
#      'profile_text_color': '1414FF',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 14934,
#     'favorite_count': 65822,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'pt'},
#    'is_quote_status': False,
#    'retweet_count': 14934,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sun Oct 30 07:12:30 +0000 2022',
#    'id': 1586617022993121280,
#    'id_str': '1586617022993121280',
#    'text': 'RT @jairbolsonaro: - Meu obrigado a Donald Trump pelo apoio! Sinto orgulho por ver que nosso trabalho por um Brasil mais seguro e mais livr…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jairbolsonaro',
#       'name': 'Jair M. Bolsonaro 2️⃣2️⃣',
#       'id': 128372940,
#       'id_str': '128372940',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1585479779083485185,
#     'id_str': '1585479779083485185',
#     'name': 'Simon Riley',
#     'screen_name': 'ghost_141_unit',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2,
#     'friends_count': 22,
#     'listed_count': 0,
#     'created_at': 'Thu Oct 27 03:53:59 +0000 2022',
#     'favourites_count': 110,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 16,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1585480563938451457/wvHVW92__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1585480563938451457/wvHVW92__normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 02:09:53 +0000 2022',
#     'id': 1586540865618591744,
#     'id_str': '1586540865618591744',
#     'text': '- Meu obrigado a Donald Trump pelo apoio! Sinto orgulho por ver que nosso trabalho por um Brasil mais seguro e mais… https://t.co/6JVsM2kMQY',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/6JVsM2kMQY',
#        'expanded_url': 'https://twitter.com/i/web/status/1586540865618591744',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 128372940,
#      'id_str': '128372940',
#      'name': 'Jair M. Bolsonaro 2️⃣2️⃣',
#      'screen_name': 'jairbolsonaro',
#      'location': 'Brasília, Brasil',
#      'description': 'Capitão Paraquedista do Exército Brasileiro. Presidente da República Federativa do Brasil. Candidato à reeleição com o número 2⃣2⃣.',
#      'url': 'https://t.co/DzletgH0tv',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/DzletgH0tv',
#          'expanded_url': 'https://t.me/jairbolsonarobrasil',
#          'display_url': 't.me/jairbolsonarob…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9626169,
#      'friends_count': 518,
#      'listed_count': 8606,
#      'created_at': 'Wed Mar 31 23:13:44 +0000 2010',
#      'favourites_count': 5979,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 15358,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '175C17',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1559734581942800385/qtN3jE9H_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1559734581942800385/qtN3jE9H_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/128372940/1663337696',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'A4E37F',
#      'profile_text_color': '1414FF',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 14934,
#     'favorite_count': 65822,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'pt'},
#    'is_quote_status': False,
#    'retweet_count': 14934,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sun Oct 30 07:12:30 +0000 2022',
#    'id': 1586617022879875073,
#    'id_str': '1586617022879875073',
#    'text': 'RT @RpsAgainstTrump: Kari Lake:\n-Believes Trump won the 2020 election, refuses to accept election results if she loses\n-Repeatedly attacked…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'RpsAgainstTrump',
#       'name': 'Republicans against Trumpism',
#       'id': 1221462414744596483,
#       'id_str': '1221462414744596483',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 16993219,
#     'id_str': '16993219',
#     'name': 'peace1 💙🇺🇸',
#     'screen_name': 'peace1',
#     'location': '',
#     'description': 'Carla - RN & animal rescuer. 🐄 🐝🐢🐕🐴Wife- mom to my 3 sons. #BBN. UK grad ☮️💙 NO DM #BidenIsMyPresident',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 45574,
#     'friends_count': 44681,
#     'listed_count': 43,
#     'created_at': 'Mon Oct 27 04:37:35 +0000 2008',
#     'favourites_count': 597121,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 439482,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1585244942217232384/aUy1pm00_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1585244942217232384/aUy1pm00_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16993219/1666401975',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 01:31:56 +0000 2022',
#     'id': 1586531316694032384,
#     'id_str': '1586531316694032384',
#     'text': 'Kari Lake:\n-Believes Trump won the 2020 election, refuses to accept election results if she loses\n-Repeatedly attac… https://t.co/bAsrKAJtXf',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/bAsrKAJtXf',
#        'expanded_url': 'https://twitter.com/i/web/status/1586531316694032384',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1221462414744596483,
#      'id_str': '1221462414744596483',
#      'name': 'Republicans against Trumpism',
#      'screen_name': 'RpsAgainstTrump',
#      'location': 'United States',
#      'description': 'Republicans and conservatives fighting Trump and Trumpism. Defend democracy at all cost!🇺🇸Hit “Super follow” to support our work & access exclusive content',
#      'url': 'https://t.co/CJiw1kwg4y',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/CJiw1kwg4y',
#          'expanded_url': 'https://reps4biden.com/',
#          'display_url': 'reps4biden.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 326136,
#      'friends_count': 4836,
#      'listed_count': 1454,
#      'created_at': 'Sun Jan 26 15:58:45 +0000 2020',
#      'favourites_count': 64687,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 70722,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1552023520347099136/tIGoFfQt_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1552023520347099136/tIGoFfQt_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1221462414744596483/1657635732',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 788,
#     'favorite_count': 1700,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 788,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:12:30 +0000 2022',
#    'id': 1586617022401634306,
#    'id_str': '1586617022401634306',
#    'text': 'RT @zecaotoninho: @jairbolsonaro Bora Brasil, Bolsonaro e Trump juntos no nosso país, o Musk, um monte de gente boa: Alexandre García, Cris…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'zecaotoninho',
#       'name': 'Antonio Carlos',
#       'id': 1099285740679237633,
#       'id_str': '1099285740679237633',
#       'indices': [3, 16]},
#      {'screen_name': 'jairbolsonaro',
#       'name': 'Jair M. Bolsonaro 2️⃣2️⃣',
#       'id': 128372940,
#       'id_str': '128372940',
#       'indices': [18, 32]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1567667220762791940,
#     'id_str': '1567667220762791940',
#     'name': 'Jorge Rached2🇧🇷🇱🇧',
#     'screen_name': 'JRached2',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 227,
#     'friends_count': 405,
#     'listed_count': 0,
#     'created_at': 'Thu Sep 08 00:13:17 +0000 2022',
#     'favourites_count': 30372,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 21541,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1567672065636941825/EUbICtWK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1567672065636941825/EUbICtWK_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 05:09:03 +0000 2022',
#     'id': 1586585955540078592,
#     'id_str': '1586585955540078592',
#     'text': '@jairbolsonaro Bora Brasil, Bolsonaro e Trump juntos no nosso país, o Musk, um monte de gente boa: Alexandre García… https://t.co/O3jMbCMtRz',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'jairbolsonaro',
#        'name': 'Jair M. Bolsonaro 2️⃣2️⃣',
#        'id': 128372940,
#        'id_str': '128372940',
#        'indices': [0, 14]}],
#      'urls': [{'url': 'https://t.co/O3jMbCMtRz',
#        'expanded_url': 'https://twitter.com/i/web/status/1586585955540078592',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1586540865618591744,
#     'in_reply_to_status_id_str': '1586540865618591744',
#     'in_reply_to_user_id': 128372940,
#     'in_reply_to_user_id_str': '128372940',
#     'in_reply_to_screen_name': 'jairbolsonaro',
#     'user': {'id': 1099285740679237633,
#      'id_str': '1099285740679237633',
#      'name': 'Antonio Carlos',
#      'screen_name': 'zecaotoninho',
#      'location': 'Santos, Brasil',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1189,
#      'friends_count': 1858,
#      'listed_count': 1,
#      'created_at': 'Sat Feb 23 12:31:59 +0000 2019',
#      'favourites_count': 44886,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3670,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1100049438477873154/OdHoKCAj_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1100049438477873154/OdHoKCAj_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 10,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'pt'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sun Oct 30 07:12:30 +0000 2022',
#    'id': 1586617021483319296,
#    'id_str': '1586617021483319296',
#    'text': 'RT @Bang_Garr: Oh my god! LOOK AT THIS! \n\nYou cant miss it! \n\nSales of the revolutionary new #memetoken start in a few days \n\nA huge team o…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'memetoken', 'indices': [93, 103]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Bang_Garr',
#       'name': 'Bang Garr',
#       'id': 1305904514487083008,
#       'id_str': '1305904514487083008',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1545546397512073220,
#     'id_str': '1545546397512073220',
#     'name': 'shia',
#     'screen_name': 'misyzyppi',
#     'location': 'home ',
#     'description': "was @/oxiygenz | if it's meant to be. it'll be.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 224,
#     'friends_count': 3863,
#     'listed_count': 1,
#     'created_at': 'Fri Jul 08 23:12:48 +0000 2022',
#     'favourites_count': 5354,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 24522,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1579851766539366402/BFkg7RjV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1579851766539366402/BFkg7RjV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1545546397512073220/1665243897',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
# ...
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 21431,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1388093846052036610/jCFsxoIF_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1388093846052036610/jCFsxoIF_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1248813977162985473/1641128703',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 14368,
#     'favorite_count': 70859,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 14368,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:12:03 +0000 2022',
#    'id': 1586616907414790146,
#    'id_str': '1586616907414790146',
#    'text': 'RT @SeegerC8: The fake news media is trying 2 say that Paul P’s. attacker is a “Trump peep” Last time I checked Conservatives don’t support…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SeegerC8',
#       'name': 'Angels & Arrows',
#       'id': 1460448162095763461,
#       'id_str': '1460448162095763461',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1471512096152162306,
#     'id_str': '1471512096152162306',
#     'name': 'Penny Mcloughlin',
#     'screen_name': 'PennyMcloughli6',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 10,
#     'friends_count': 29,
#     'listed_count': 0,
#     'created_at': 'Thu Dec 16 16:07:22 +0000 2021',
#     'favourites_count': 778,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 343,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 05:15:42 +0000 2022',
#     'id': 1586225239108640768,
#     'id_str': '1586225239108640768',
#     'text': 'The fake news media is trying 2 say that Paul P’s. attacker is a “Trump peep” Last time I checked Conservatives don… https://t.co/R4pslEC81Z',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/R4pslEC81Z',
#        'expanded_url': 'https://twitter.com/i/web/status/1586225239108640768',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1460448162095763461,
#      'id_str': '1460448162095763461',
#      'name': 'Angels & Arrows',
#      'screen_name': 'SeegerC8',
#      'location': 'United States',
#      'description': 'Jesus, Free American, Chief Conservative, Mother, Wife, Friend. No DM’s for Dates. What part of married & Christian confuses you?',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3295,
#      'friends_count': 2991,
#      'listed_count': 5,
#      'created_at': 'Tue Nov 16 03:23:11 +0000 2021',
#      'favourites_count': 28049,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 13191,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1586506401765113856/eb1FTmcc_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1586506401765113856/eb1FTmcc_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1460448162095763461/1663442703',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 89,
#     'favorite_count': 231,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 89,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:12:03 +0000 2022',
#    'id': 1586616907007827968,
#    'id_str': '1586616907007827968',
#    'text': '@TomFitton You spelled Donald Trump wrong. 🤡',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TomFitton',
#       'name': 'Tom Fitton',
#       'id': 18266688,
#       'id_str': '18266688',
#       'indices': [0, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1586456769596989440,
#    'in_reply_to_status_id_str': '1586456769596989440',
#    'in_reply_to_user_id': 18266688,
#    'in_reply_to_user_id_str': '18266688',
#    'in_reply_to_screen_name': 'TomFitton',
#    'user': {'id': 788456089423458304,
#     'id_str': '788456089423458304',
#     'name': 'Mark Masters',
#     'screen_name': 'Sumoslammers1',
#     'location': 'Utah, USA',
#     'description': 'Diehard Ute, Played at Weber State-long ago, Will always have a take/opinion, Love my Family. Admit to being a bad Speller. Please, no right wing yahoo’s! 😊',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 648,
#     'friends_count': 630,
#     'listed_count': 0,
#     'created_at': 'Tue Oct 18 19:05:55 +0000 2016',
#     'favourites_count': 69354,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 26600,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1044906896463806465/Cfi3S_as_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1044906896463806465/Cfi3S_as_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/788456089423458304/1666239792',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 30 07:12:02 +0000 2022',
#    'id': 1586616903379861507,
#    'id_str': '1586616903379861507',
#    'text': 'RT @Mag71Mag: Miguel Ángel Rodríguez quiere efectuar las políticas de Donald Trump en España🇪🇸 y Ayuso es la elegida para llevarlas acabo p…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Mag71Mag',
#       'name': 'MAG🌹',
#       'id': 1104062345691713541,
#       'id_str': '1104062345691713541',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4589558963,
#     'id_str': '4589558963',
#     'name': 'Carlos',
#     'screen_name': 'carchete',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 102,
#     'friends_count': 73,
#     'listed_count': 2,
#     'created_at': 'Thu Dec 24 13:23:22 +0000 2015',
#     'favourites_count': 41721,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 55955,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 13:39:43 +0000 2022',
#     'id': 1586352081019240448,
#     'id_str': '1586352081019240448',
#     'text': 'Miguel Ángel Rodríguez quiere efectuar las políticas de Donald Trump en España🇪🇸 y Ayuso es la elegida para llevarl… https://t.co/9FNSUjWbAO',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9FNSUjWbAO',
#        'expanded_url': 'https://twitter.com/i/web/status/1586352081019240448',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1104062345691713541,
#      'id_str': '1104062345691713541',
#      'name': 'MAG🌹',
#      'screen_name': 'Mag71Mag',
#      'location': '',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 15457,
#      'friends_count': 3520,
#      'listed_count': 32,
#      'created_at': 'Fri Mar 08 16:52:30 +0000 2019',
#      'favourites_count': 71940,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 27446,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1538489605556776960/oWrBZTIv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1538489605556776960/oWrBZTIv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1104062345691713541/1653276521',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 301,
#     'favorite_count': 740,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'es'},
#    'is_quote_status': False,
#    'retweet_count': 301,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'}],
#  'search_metadata': {'completed_in': 0.133,
#   'max_id': 1586617033109786624,
#   'max_id_str': '1586617033109786624',
#   'next_results': '?max_id=1586616903379861506&q=TRump&count=100&include_entities=1',
#   'query': 'TRump',
#   'refresh_url': '?since_id=1586617033109786624&q=TRump&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
import pandas as pd

# %%
all_items=results['statuses']

# %%
df=pd.DataFrame(all_items)

# %%
df
# Out:
#                         created_at                   id               id_str  \
# 0   Sun Oct 30 07:12:33 +0000 2022  1586617033109786624  1586617033109786624
# 1   Sun Oct 30 07:12:32 +0000 2022  1586617029548810244  1586617029548810244
# 2   Sun Oct 30 07:12:31 +0000 2022  1586617026306457600  1586617026306457600
# 3   Sun Oct 30 07:12:31 +0000 2022  1586617025757151235  1586617025757151235
# 4   Sun Oct 30 07:12:31 +0000 2022  1586617024775847936  1586617024775847936
# ..                             ...                  ...                  ...
# 95  Sun Oct 30 07:12:03 +0000 2022  1586616909780242432  1586616909780242432
# 96  Sun Oct 30 07:12:03 +0000 2022  1586616907955769346  1586616907955769346
# 97  Sun Oct 30 07:12:03 +0000 2022  1586616907414790146  1586616907414790146
# 98  Sun Oct 30 07:12:03 +0000 2022  1586616907007827968  1586616907007827968
# 99  Sun Oct 30 07:12:02 +0000 2022  1586616903379861507  1586616903379861507
#
#                                                  text  truncated  \
# 0   @TheLeoTerrell But this guy, who history shows...      False
# 1   @blueheartedly He should reinstate it but I ho...      False
# 2   RT @chitaglorya3rd: Oh my god! LOOK AT THIS!\n...      False
# 3   @ProtocolUpdate @SpeakerPelosi Do show evidenc...       True
# 4   RT @taegiveaway: Oh my god! LOOK AT THIS! \n\n...      False
# ..                                                ...        ...
# 95  RT @AliVelshi: "Democracy may very well be dec...      False
# 96  RT @LebergerDavid: Defeated Former President D...      False
# 97  RT @SeegerC8: The fake news media is trying 2 ...      False
# 98       @TomFitton You spelled Donald Trump wrong. 🤡      False
# 99  RT @Mag71Mag: Miguel Ángel Rodríguez quiere ef...      False
#
#                                              entities  \
# 0   {'hashtags': [], 'symbols': [], 'user_mentions...
# 1   {'hashtags': [], 'symbols': [], 'user_mentions...
# 2   {'hashtags': [{'text': 'memetoken', 'indices':...
# 3   {'hashtags': [], 'symbols': [], 'user_mentions...
# 4   {'hashtags': [{'text': 'memetoken', 'indices':...
# ..                                                ...
# 95  {'hashtags': [], 'symbols': [], 'user_mentions...
# 96  {'hashtags': [], 'symbols': [], 'user_mentions...
# 97  {'hashtags': [], 'symbols': [], 'user_mentions...
# 98  {'hashtags': [], 'symbols': [], 'user_mentions...
# 99  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                              metadata  \
# 0   {'iso_language_code': 'en', 'result_type': 're...
# 1   {'iso_language_code': 'en', 'result_type': 're...
# 2   {'iso_language_code': 'en', 'result_type': 're...
# 3   {'iso_language_code': 'en', 'result_type': 're...
# 4   {'iso_language_code': 'en', 'result_type': 're...
# ..                                                ...
# 95  {'iso_language_code': 'en', 'result_type': 're...
# 96  {'iso_language_code': 'en', 'result_type': 're...
# 97  {'iso_language_code': 'en', 'result_type': 're...
# 98  {'iso_language_code': 'en', 'result_type': 're...
# 99  {'iso_language_code': 'es', 'result_type': 're...
#
#                                                source  in_reply_to_status_id  \
# 0   <a href="http://twitter.com/download/iphone" r...           1.586577e+18
# 1   <a href="http://twitter.com/download/android" ...           1.586339e+18
# 2   <a href="http://twitter.com/download/android" ...                    NaN
# 3   <a href="http://twitter.com/download/iphone" r...           1.586586e+18
# 4   <a href="http://twitter.com/download/android" ...                    NaN
# ..                                                ...                    ...
# 95  <a href="http://twitter.com/download/android" ...                    NaN
# 96  <a href="http://twitter.com/download/android" ...                    NaN
# 97  <a href="http://twitter.com/download/iphone" r...                    NaN
# 98  <a href="http://twitter.com/download/iphone" r...           1.586457e+18
# 99  <a href="http://twitter.com/download/android" ...                    NaN
#
#    in_reply_to_status_id_str  ...  favorite_count favorited retweeted  \
# 0        1586577370810458113  ...               0     False     False
# 1        1586339257928470537  ...               0     False     False
# 2                       None  ...               0     False     False
# 3        1586586247287304193  ...               0     False     False
# 4                       None  ...               0     False     False
# ..                       ...  ...             ...       ...       ...
# 95                      None  ...               0     False     False
# 96                      None  ...               0     False     False
# 97                      None  ...               0     False     False
# 98       1586456769596989440  ...               0     False     False
# 99                      None  ...               0     False     False
#
#    possibly_sensitive lang                                   retweeted_status  \
# 0               False   en                                                NaN
# 1                 NaN   en                                                NaN
# 2                 NaN   en  {'created_at': 'Sun Oct 30 03:13:44 +0000 2022...
# 3                 NaN   en                                                NaN
# 4                 NaN   en  {'created_at': 'Sat Oct 29 14:01:25 +0000 2022...
# ..                ...  ...                                                ...
# 95                NaN   en  {'created_at': 'Sat Oct 29 15:42:01 +0000 2022...
# 96              False   en  {'created_at': 'Sun Mar 27 03:15:09 +0000 2022...
# 97                NaN   en  {'created_at': 'Sat Oct 29 05:15:42 +0000 2022...
# 98                NaN   en                                                NaN
# 99                NaN   es  {'created_at': 'Sat Oct 29 13:39:43 +0000 2022...
#
#    quoted_status_id quoted_status_id_str  quoted_status  \
# 0               NaN                  NaN            NaN
# 1               NaN                  NaN            NaN
# 2               NaN                  NaN            NaN
# 3               NaN                  NaN            NaN
# 4               NaN                  NaN            NaN
# ..              ...                  ...            ...
# 95              NaN                  NaN            NaN
# 96              NaN                  NaN            NaN
# 97              NaN                  NaN            NaN
# 98              NaN                  NaN            NaN
# 99              NaN                  NaN            NaN
#
#                                     extended_entities
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  {'media': [{'id': 1507919120058171399, 'id_str...
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
# [100 rows x 30 columns]

# %%
users=pd.DataFrame(d["user"] for d in results["statuses"])

# %%
users.head()
# Out:
#                     id               id_str                         name  \
# 0           2619172510           2619172510  He looks like a Tyrant. 🤬🤡💩
# 1             47800374             47800374       Bartleby the Scrivener
# 2  1395520387841019904  1395520387841019904                 Tommy Slebew
# 3  1541843374029918209  1541843374029918209              Jason Carpenter
# 4  1358592231964172290  1358592231964172290                    eskrim 🍨🍰
#
#        screen_name                location  \
# 0  LynneJordanActs
# 1        BartlebyX              Taylor, MI
# 2      0xShelbyWin  Shelby Company Limited
# 3      Parzival418           Punjar, Aerth
# 4      selenaxlele               Indonesia
#
#                                          description   url  \
# 0  He armed us. Divided us. Stole the money. Sent...  None
# 1  John 3:16, Christian, dad, pro adoption, INTJ,...  None
# 2  by oouwdaaa of da peaky fooooocking bloinde'sssz!  None
# 3  Future dad. Goblin king. Pig faced orcs is bes...  None
# 4  𓆩⚜️𓆪 Akun Mobile Legend ku kalau gacha emang b...  None
#
#                         entities  protected  followers_count  ...  \
# 0  {'description': {'urls': []}}      False              184  ...
# 1  {'description': {'urls': []}}      False              491  ...
# 2  {'description': {'urls': []}}      False              138  ...
# 3  {'description': {'urls': []}}      False              108  ...
# 4  {'description': {'urls': []}}      False               81  ...
#
#    profile_text_color  profile_use_background_image has_extended_profile  \
# 0              333333                          True                False
# 1              333333                          True                 True
# 2              333333                          True                False
# 3              333333                          True                 True
# 4              333333                          True                False
#
#    default_profile default_profile_image following  follow_request_sent  \
# 0            False                 False      None                 None
# 1             True                 False      None                 None
# 2             True                 False      None                 None
# 3             True                 False      None                 None
# 4             True                 False      None                 None
#
#    notifications  translator_type withheld_in_countries
# 0           None             none                    []
# 1           None             none                    []
# 2           None             none                    []
# 3           None             none                    []
# 4           None             none                    []
#
# [5 rows x 43 columns]

# %%
tdf=df.merge(users,left_index=True,right_index=True)

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 73 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   created_at_x                        100 non-null    object
#  1   id_x                                100 non-null    int64
#  2   id_str_x                            100 non-null    object
#  3   text                                100 non-null    object
#  4   truncated                           100 non-null    bool
#  5   entities_x                          100 non-null    object
#  6   metadata                            100 non-null    object
#  7   source                              100 non-null    object
#  8   in_reply_to_status_id               15 non-null     float64
#  9   in_reply_to_status_id_str           15 non-null     object
#  10  in_reply_to_user_id                 15 non-null     float64
#  11  in_reply_to_user_id_str             15 non-null     object
#  12  in_reply_to_screen_name             15 non-null     object
#  13  user                                100 non-null    object
#  14  geo                                 0 non-null      object
#  15  coordinates                         0 non-null      object
#  16  place                               0 non-null      object
#  17  contributors                        0 non-null      object
#  18  is_quote_status                     100 non-null    bool
#  19  retweet_count                       100 non-null    int64
#  20  favorite_count                      100 non-null    int64
#  21  favorited                           100 non-null    bool
#  22  retweeted                           100 non-null    bool
#  23  possibly_sensitive                  10 non-null     object
#  24  lang_x                              100 non-null    object
#  25  retweeted_status                    78 non-null     object
#  26  quoted_status_id                    4 non-null      float64
#  27  quoted_status_id_str                4 non-null      object
#  28  quoted_status                       1 non-null      object
#  29  extended_entities                   1 non-null      object
#  30  id_y                                100 non-null    int64
#  31  id_str_y                            100 non-null    object
#  32  name                                100 non-null    object
#  33  screen_name                         100 non-null    object
#  34  location                            100 non-null    object
#  35  description                         100 non-null    object
#  36  url                                 10 non-null     object
#  37  entities_y                          100 non-null    object
#  38  protected                           100 non-null    bool
#  39  followers_count                     100 non-null    int64
#  40  friends_count                       100 non-null    int64
#  41  listed_count                        100 non-null    int64
#  42  created_at_y                        100 non-null    object
#  43  favourites_count                    100 non-null    int64
#  44  utc_offset                          0 non-null      object
#  45  time_zone                           0 non-null      object
#  46  geo_enabled                         100 non-null    bool
#  47  verified                            100 non-null    bool
#  48  statuses_count                      100 non-null    int64
#  49  lang_y                              0 non-null      object
#  50  contributors_enabled                100 non-null    bool
#  51  is_translator                       100 non-null    bool
#  52  is_translation_enabled              100 non-null    bool
#  53  profile_background_color            100 non-null    object
#  54  profile_background_image_url        36 non-null     object
#  55  profile_background_image_url_https  36 non-null     object
#  56  profile_background_tile             100 non-null    bool
#  57  profile_image_url                   100 non-null    object
#  58  profile_image_url_https             100 non-null    object
#  59  profile_banner_url                  68 non-null     object
#  60  profile_link_color                  100 non-null    object
#  61  profile_sidebar_border_color        100 non-null    object
#  62  profile_sidebar_fill_color          100 non-null    object
#  63  profile_text_color                  100 non-null    object
#  64  profile_use_background_image        100 non-null    bool
#  65  has_extended_profile                100 non-null    bool
#  66  default_profile                     100 non-null    bool
#  67  default_profile_image               100 non-null    bool
#  68  following                           0 non-null      object
#  69  follow_request_sent                 0 non-null      object
#  70  notifications                       0 non-null      object
#  71  translator_type                     100 non-null    object
#  72  withheld_in_countries               100 non-null    object
# dtypes: bool(15), float64(3), int64(9), object(46)
# memory usage: 46.9+ KB

# %%
tdf.location.value_counts().plot(kind="bar",figsize=(10,6));
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128048 (\N{RABBIT FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Sentiment Analysis   #kelimelerin poz. neg. gösterir

# %%
from textblob import TextBlob

# %%
TextBlob ("the best").polarity
# Out:
# 1.0

# %%
TextBlob ("the best").sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)

# %%
def detect_sentiment(text):
    return TextBlob(text).sentiment.polarity

# %%
df2=tdf[["text"]]

# %%
df2
# Out:
#                                                  text
# 0   @TheLeoTerrell But this guy, who history shows...
# 1   @blueheartedly He should reinstate it but I ho...
# 2   RT @chitaglorya3rd: Oh my god! LOOK AT THIS!\n...
# 3   @ProtocolUpdate @SpeakerPelosi Do show evidenc...
# 4   RT @taegiveaway: Oh my god! LOOK AT THIS! \n\n...
# ..                                                ...
# 95  RT @AliVelshi: "Democracy may very well be dec...
# 96  RT @LebergerDavid: Defeated Former President D...
# 97  RT @SeegerC8: The fake news media is trying 2 ...
# 98       @TomFitton You spelled Donald Trump wrong. 🤡
# 99  RT @Mag71Mag: Miguel Ángel Rodríguez quiere ef...
#
# [100 rows x 1 columns]

# %%
df2.head()
# Out:
#                                                 text
# 0  @TheLeoTerrell But this guy, who history shows...
# 1  @blueheartedly He should reinstate it but I ho...
# 2  RT @chitaglorya3rd: Oh my god! LOOK AT THIS!\n...
# 3  @ProtocolUpdate @SpeakerPelosi Do show evidenc...
# 4  RT @taegiveaway: Oh my god! LOOK AT THIS! \n\n...

# %%
df2["sentiment"]=df2["text"].apply(detect_sentiment)
# Out:
# C:\Users\bayan feminist\AppData\Local\Temp\ipykernel_29424\1909004749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sentiment"]=df2["text"].apply(detect_sentiment)

# %%
df2.head()
# Out:
#                                                 text  sentiment
# 0  @TheLeoTerrell But this guy, who history shows...   0.000000
# 1  @blueheartedly He should reinstate it but I ho...   0.000000
# 2  RT @chitaglorya3rd: Oh my god! LOOK AT THIS!\n...   0.112121
# 3  @ProtocolUpdate @SpeakerPelosi Do show evidenc...   0.000000
# 4  RT @taegiveaway: Oh my god! LOOK AT THIS! \n\n...   0.112121

# %%
df2.sentiment.value_counts()
# Out:
#  0.000000    43
#  0.112121    22
# -0.500000     3
#  0.200000     3
# -0.350000     2
# -0.400000     2
#  0.400000     2
#  0.500000     2
# -0.083333     1
#  0.166667     1
# -0.125000     1
#  0.375000     1
# -0.400000     1
# -0.200000     1
#  0.266667     1
# -0.133333     1
# -0.300000     1
#  0.136364     1
#  0.780000     1
# -0.800000     1
#  0.265848     1
#  0.250000     1
# -0.291667     1
#  0.700000     1
#  0.100000     1
#  0.350000     1
#  0.087500     1
# -0.100000     1
# -0.250000     1
# Name: sentiment, dtype: int64

# %%
df2["text"]=df2["text"].str.lower()
# Out:
# C:\Users\bayan feminist\AppData\Local\Temp\ipykernel_29424\1934567259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.lower()

# %%
df2["text"]=df2["text"].str.replace('[^\w\s]','')
# Out:
# C:\Users\bayan feminist\AppData\Local\Temp\ipykernel_29424\2430991166.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["text"]=df2["text"].str.replace('[^\w\s]','')
# C:\Users\bayan feminist\AppData\Local\Temp\ipykernel_29424\2430991166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace('[^\w\s]','')

# %%
df2["text"]=df2["text"].str.replace('\d+','')
# Out:
# C:\Users\bayan feminist\AppData\Local\Temp\ipykernel_29424\1091199844.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["text"]=df2["text"].str.replace('\d+','')
# C:\Users\bayan feminist\AppData\Local\Temp\ipykernel_29424\1091199844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace('\d+','')

# %%
df2["text"]=df2["text"].str.replace('\n','').replace('\r','')
# Out:
# C:\Users\bayan feminist\AppData\Local\Temp\ipykernel_29424\2655869773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace('\n','').replace('\r','')

# %%
from wordcloud import STOPWORDS
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
def wc(data,bgcolor):
    plt.figure(figsize=(10,10))
    mask=np.array(Image.open("togg.jpg"))
    wc=WordCloud(background_color=bgcolor,stopwords=STOPWORDS,mask=mask)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis("off")

# %%
wc(df2.text,'white')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [113], in <cell line: 1>()
# ----> 1 wc(df2.text,'white')
#
# Input In [112], in wc(data, bgcolor)
#       1 def wc(data,bgcolor):
#       2     plt.figure(figsize=(10,10))
# ----> 3     mask=np.array(Image.open("togg.jpg"))
#       4     wc=WordCloud(background_color=bgcolor,stopwords=STOPWORDS,mask=mask)
#       5     wc.generate(' '.join(data))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py:2953, in open(fp, mode, formats)
#    2950     filename = fp
#    2952 if filename:
# -> 2953     fp = builtins.open(filename, "rb")
#    2954     exclusive_fp = True
#    2956 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'togg.jpg'

# %%
#1=positive 
#2-negatif
#3-nötr

def sentiment2(sent):
    if sent<-0.02 :
        return 2 
    elif sent >0.02 :
        return 1
    else:
        return 0

# %%
df2["sent"]=df2["sentiment"].apply(sentiment2)
# Out:
# C:\Users\bayan feminist\AppData\Local\Temp\ipykernel_29424\3383788003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sent"]=df2["sentiment"].apply(sentiment2)

# %%
df2.head()
# Out:
#                                                 text  sentiment  sent
# 0  theleoterrell but this guy who history shows h...   0.000000     0
# 1  blueheartedly he should reinstate it but i hop...   0.000000     0
# 2  rt chitagloryard oh my god look at thisyou can...   0.112121     1
# 3  protocolupdate speakerpelosi do show evidence ...   0.000000     0
# 4  rt taegiveaway oh my god look at this you cant...   0.112121     1

# %%
import seaborn as sns

# %%
sns.countplot(df2.sent);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x=df2.text
y=df2.sent

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
vect=CountVectorizer(stop_words="english")

# %%
x=vect.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.15)

# %%
mb=MultinomialNB()

# %%
tahmin=mb.fit(x_train,y_train).predict(x_test)

# %%
accuracy_score(tahmin,y_test) # verimiz 100 satirlik
# Out:
# 0.6

# %%
from sklearn.tree import DecisionTreeClassifier
